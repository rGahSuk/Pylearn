# %%
api = '1572cd7c-0146-49ba-b4bf-75047f2eaf01'
secret = 'l0g8nnfkpr'
redirect_url = 'https://www.kushagrbakshi.com/'
state = 'kush'

# %%
url = f"https://api.upstox.com/v2/login/authorization/dialog?response_type=code&client_id={api}&redirect_uri={redirect_url}&state={state}"
url
# Out:
# 'https://api.upstox.com/v2/login/authorization/dialog?response_type=code&client_id=1572cd7c-0146-49ba-b4bf-75047f2eaf01&redirect_uri=https://www.kushagrbakshi.com/&state=kush'

# %%
auth_code = input("Enter the authorization code: ")
print("Auth Code =", auth_code)
# Out:
# Auth Code = 9jY-uZ

# %%
import upstox_client
from upstox_client.rest import ApiException

api_instance = upstox_client.LoginApi()
api_version = '2.0'
code = auth_code
client_id = api
client_secret = secret
redirect_uri = 'https://www.kushagrbakshi.com/'
grant_type = 'authorization_code'

try:
    # Get token API
    api_response = api_instance.token(api_version, code=code, client_id=client_id, client_secret=client_secret,
                                      redirect_uri=redirect_uri, grant_type=grant_type)
    print(api_response)
except ApiException as e:
    print("Exception when calling LoginApi->token: %s\n" % e)
# Out:
# {'access_token': 'eyJ0eXAiOiJKV1QiLCJrZXlfaWQiOiJza192MS4wIiwiYWxnIjoiSFMyNTYifQ.eyJzdWIiOiI1MkM0S1QiLCJqdGkiOiI2YTVhMGNiNGM2MzhmMDYzZjY2Y2JlNjEiLCJpc011bHRpQ2xpZW50IjpmYWxzZSwiaXNQbHVzUGxhbiI6dHJ1ZSwiaWF0IjoxNzg0Mjg2Mzg4LCJpc3MiOiJ1ZGFwaS1nYXRld2F5LXNlcnZpY2UiLCJleHAiOjE3ODQzMjU2MDB9.p9OmTqbxldTSEbav5PaFqYLQbGy0Gyur2yV4b_hx5HM',
#  'broker': 'UPSTOX',
#  'email': 'kushagrbakshi12@gmail.com',
#  'exchanges': ['BSE', 'NSE', 'BCD', 'CDS', 'BFO', 'NFO', 'MCX'],
#  'extended_token': 'eyJ0eXAiOiJKV1QiLCJrZXlfaWQiOiJza192MS4wIiwiYWxnIjoiSFMyNTYifQ.eyJzdWIiOiI1MkM0S1QiLCJqdGkiOiI2YTVhMGNiNGM2MzhmMDYzZjY2Y2JlNjIiLCJpc011bHRpQ2xpZW50IjpmYWxzZSwiaXNQbHVzUGxhbiI6dHJ1ZSwiaXNFeHRlbmRlZCI6dHJ1ZSwiaWF0IjoxNzg0Mjg2Mzg4LCJpc3MiOiJ1ZGFwaS1nYXRld2F5LXNlcnZpY2UiLCJleHAiOjE4MTU4NjE2MDB9.2v9BmZp2elmIjspVPgqL-flsOIBdcP_W5XnvhyeiS3E',
#  'is_active': True,
#  'order_types': ['MARKET', 'LIMIT', 'SL', 'SL-M'],
#  'poa': None,
#  'products': ['OCO', 'D', 'CO', 'I'],
#  'user_id': '52C4KT',
# ...

# %%
access_token = api_response.access_token
